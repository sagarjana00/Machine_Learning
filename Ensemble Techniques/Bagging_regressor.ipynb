# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

x, y = make_regression(n_samples=1000, n_features=10, noise=0.1, random_state=1)

# %%
x_train,x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
lr = LinearRegression()
dtr = DecisionTreeRegressor()
svr = SVR(kernel="linear")

# %%
from sklearn.ensemble import VotingRegressor
ensemble_regressor = VotingRegressor(estimators=[("lr", lr), ("dtr", dtr), ("SVR",svr)])

# %%
ensemble_regressor.fit(x_train,y_train)
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()),
#                             ('dtr', DecisionTreeRegressor()),
#                             ('SVR', SVR(kernel='linear'))])

# %%
y_pred = ensemble_regressor.predict(x_test)
y_pred
# Out:
# array([ 5.11872904e+01,  4.08445786e+01, -8.15441286e+01, -6.20344726e+01,
#         5.04501120e+02,  3.25503446e+02,  4.55226995e+01, -4.12408937e+01,
#        -1.06234323e+02, -7.12938166e+01, -1.00334110e+02,  4.07179663e+01,
#        -7.44684834e+01, -1.43265426e+02, -3.11551260e+02, -1.42527047e+02,
#        -2.92020843e+02, -1.63338570e+02, -2.93557915e+01, -1.88701563e+02,
#        -4.43823066e+01, -1.36205980e+02,  3.02532496e+02, -1.95609800e+02,
#         3.01606892e+00,  1.91732034e+02,  2.37175966e+02,  5.80558461e+01,
#        -6.66816141e+01,  1.12847310e+02,  1.99951204e+01,  2.42099555e+02,
#         1.33778666e+02,  2.73595711e+02,  1.21533509e+02,  1.14246987e+02,
#         4.67752330e+01, -3.70521248e+02, -1.84147775e+02, -8.22790107e+01,
#        -6.88778754e+00, -1.00667716e+02,  1.08209630e+02, -1.32661159e+02,
#         8.23614882e+01,  2.78836407e+01,  1.85416361e+02, -1.21929389e+02,
#         1.55261977e+02, -2.98783021e+02,  2.17708614e+02,  3.64426153e+02,
#        -2.21151696e+02,  6.83553684e+01, -4.11026328e+01,  1.01204531e+02,
#         1.84329453e+02,  5.00167592e+01,  3.95606375e+01,  9.19798698e+01,
#         6.34701855e+01, -4.27854105e+02,  4.07913956e+02,  1.26840281e+02,
#         2.16527655e+01, -1.77670581e+02, -6.90548031e+01,  2.84538883e+00,
#        -6.83385779e+01,  1.39016033e+02,  4.64837150e+02,  4.37681998e+01,
#        -5.17287977e+01, -7.50182041e+01,  1.55472180e+02, -1.44101187e+02,
#        -5.28884544e+01,  2.99871692e+01,  3.20073129e+00,  1.23810510e+01,
#        -9.72728400e+01,  1.86115505e+02, -7.47055718e+01,  6.92049707e+01,
#        -1.34108916e+02,  1.81396909e+02,  3.12437399e+01, -1.12488450e+02,
